# %% [markdown]
# ## Analyse exploratoire

# %% [markdown]
# #### Description des données

# %%
# Importation des bibliothèques nécessaires
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('2016_Building_Energy_Benchmarking.csv')

# %%
df.shape
# Out:
# (3376, 46)

# %%
df.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
# 1              2      2016  NonResidential               Hotel
# 2              3      2016  NonResidential               Hotel
# 3              5      2016  NonResidential               Hotel
# 4              8      2016  NonResidential               Hotel
#
#                   PropertyName          Address     City State  ZipCode  \
# 0         Mayflower park hotel    405 Olive way  Seattle    WA  98101.0
# 1              Paramount Hotel  724 Pine street  Seattle    WA  98101.0
# 2      5673-The Westin Seattle  1900 5th Avenue  Seattle    WA  98101.0
# 3                    HOTEL MAX   620 STEWART ST  Seattle    WA  98101.0
# 4  WARWICK SEATTLE HOTEL (ID8)    401 LENORA ST  Seattle    WA  98121.0
#
#   TaxParcelIdentificationNumber  ...  Electricity(kWh) Electricity(kBtu)  \
# 0                    0659000030  ...      1.156514e+06         3946027.0
# 1                    0659000220  ...      9.504252e+05         3242851.0
# 2                    0659000475  ...      1.451544e+07        49526664.0
# 3                    0659000640  ...      8.115253e+05         2768924.0
# 4                    0659000970  ...      1.573449e+06         5368607.0
#
#    NaturalGas(therms)  NaturalGas(kBtu)  DefaultData  Comments  \
# 0         12764.52930         1276453.0        False       NaN
# 1         51450.81641         5145082.0        False       NaN
# 2         14938.00000         1493800.0        False       NaN
# 3         18112.13086         1811213.0        False       NaN
# 4         88039.98438         8803998.0        False       NaN
#
#    ComplianceStatus  Outlier  TotalGHGEmissions  GHGEmissionsIntensity
# 0         Compliant      NaN             249.98                   2.83
# 1         Compliant      NaN             295.86                   2.86
# 2         Compliant      NaN            2089.28                   2.19
# 3         Compliant      NaN             286.43                   4.67
# 4         Compliant      NaN             505.01                   2.88
#
# [5 rows x 46 columns]

# %%
df.describe()
# Out:
#        OSEBuildingID  DataYear       ZipCode  CouncilDistrictCode  \
# count    3376.000000    3376.0   3360.000000          3376.000000
# mean    21208.991114    2016.0  98116.949107             4.439277
# std     12223.757015       0.0     18.615205             2.120625
# min         1.000000    2016.0  98006.000000             1.000000
# 25%     19990.750000    2016.0  98105.000000             3.000000
# 50%     23112.000000    2016.0  98115.000000             4.000000
# 75%     25994.250000    2016.0  98122.000000             7.000000
# max     50226.000000    2016.0  98272.000000             7.000000
#
#           Latitude    Longitude    YearBuilt  NumberofBuildings  \
# count  3376.000000  3376.000000  3376.000000        3368.000000
# mean     47.624033  -122.334795  1968.573164           1.106888
# std       0.047758     0.027203    33.088156           2.108402
# min      47.499170  -122.414250  1900.000000           0.000000
# 25%      47.599860  -122.350662  1948.000000           1.000000
# 50%      47.618675  -122.332495  1975.000000           1.000000
# 75%      47.657115  -122.319407  1997.000000           1.000000
# max      47.733870  -122.220966  2015.000000         111.000000
#
#        NumberofFloors  PropertyGFATotal  ...  SiteEnergyUse(kBtu)  \
# count     3376.000000      3.376000e+03  ...         3.371000e+03
# mean         4.709123      9.483354e+04  ...         5.403667e+06
# std          5.494465      2.188376e+05  ...         2.161063e+07
# min          0.000000      1.128500e+04  ...         0.000000e+00
# 25%          2.000000      2.848700e+04  ...         9.251286e+05
# 50%          4.000000      4.417500e+04  ...         1.803753e+06
# 75%          5.000000      9.099200e+04  ...         4.222455e+06
# max         99.000000      9.320156e+06  ...         8.739237e+08
#
#        SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  Electricity(kWh)  \
# count           3.370000e+03    3.367000e+03      3.367000e+03
# mean            5.276726e+06    2.745959e+05      1.086639e+06
# std             1.593879e+07    3.912173e+06      4.352478e+06
# min             0.000000e+00    0.000000e+00     -3.382680e+04
# 25%             9.701822e+05    0.000000e+00      1.874229e+05
# 50%             1.904452e+06    0.000000e+00      3.451299e+05
# 75%             4.381429e+06    0.000000e+00      8.293178e+05
# max             4.716139e+08    1.349435e+08      1.925775e+08
#
#        Electricity(kBtu)  NaturalGas(therms)  NaturalGas(kBtu)  Comments  \
# count       3.367000e+03        3.367000e+03      3.367000e+03       0.0
# mean        3.707612e+06        1.368505e+04      1.368505e+06       NaN
# std         1.485066e+07        6.709781e+04      6.709781e+06       NaN
# min        -1.154170e+05        0.000000e+00      0.000000e+00       NaN
# 25%         6.394870e+05        0.000000e+00      0.000000e+00       NaN
# 50%         1.177583e+06        3.237538e+03      3.237540e+05       NaN
# 75%         2.829632e+06        1.189033e+04      1.189034e+06       NaN
# max         6.570744e+08        2.979090e+06      2.979090e+08       NaN
#
#        TotalGHGEmissions  GHGEmissionsIntensity
# count        3367.000000            3367.000000
# mean          119.723971               1.175916
# std           538.832227               1.821452
# min            -0.800000              -0.020000
# 25%             9.495000               0.210000
# 50%            33.920000               0.610000
# 75%            93.940000               1.370000
# max         16870.980000              34.090000
#
# [8 rows x 30 columns]

# %%
#Heatmap appliqué pour visualiser les données manquantes
plt.rcParams["figure.figsize"] = (28,4)
sns.heatmap(df.isnull(),yticklabels=False, cbar=False,cmap='viridis')

# %%
# Calcul du taux de remplissage par colonne:
col= df.columns.tolist()
df_rate= pd.DataFrame(columns=['col','Taux de remplissage'])
for column in col:
    col_obj= df[column]
    null_rate=round(1-(col_obj.isnull().sum()/float(len(df))),2)
    df_rate= df_rate.append({'col':column, 'Taux de remplissage':null_rate },ignore_index=True)

# %%
df_rate.head()
# Out:
#                    col  Taux de remplissage
# 0        OSEBuildingID                  1.0
# 1             DataYear                  1.0
# 2         BuildingType                  1.0
# 3  PrimaryPropertyType                  1.0
# 4         PropertyName                  1.0

# %%
len(df_rate[df_rate['Taux de remplissage']==1])
# Out:
# 36

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3376 entries, 0 to 3375
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   OSEBuildingID                    3376 non-null   int64
#  1   DataYear                         3376 non-null   int64
#  2   BuildingType                     3376 non-null   object
#  3   PrimaryPropertyType              3376 non-null   object
#  4   PropertyName                     3376 non-null   object
#  5   Address                          3376 non-null   object
#  6   City                             3376 non-null   object
#  7   State                            3376 non-null   object
#  8   ZipCode                          3360 non-null   float64
#  9   TaxParcelIdentificationNumber    3376 non-null   object
#  10  CouncilDistrictCode              3376 non-null   int64
#  11  Neighborhood                     3376 non-null   object
#  12  Latitude                         3376 non-null   float64
#  13  Longitude                        3376 non-null   float64
#  14  YearBuilt                        3376 non-null   int64
#  15  NumberofBuildings                3368 non-null   float64
#  16  NumberofFloors                   3376 non-null   int64
#  17  PropertyGFATotal                 3376 non-null   int64
#  18  PropertyGFAParking               3376 non-null   int64
#  19  PropertyGFABuilding(s)           3376 non-null   int64
#  20  ListOfAllPropertyUseTypes        3367 non-null   object
#  21  LargestPropertyUseType           3356 non-null   object
#  22  LargestPropertyUseTypeGFA        3356 non-null   float64
#  23  SecondLargestPropertyUseType     1679 non-null   object
#  24  SecondLargestPropertyUseTypeGFA  1679 non-null   float64
#  25  ThirdLargestPropertyUseType      596 non-null    object
#  26  ThirdLargestPropertyUseTypeGFA   596 non-null    float64
#  27  YearsENERGYSTARCertified         119 non-null    object
#  28  ENERGYSTARScore                  2533 non-null   float64
#  29  SiteEUI(kBtu/sf)                 3369 non-null   float64
#  30  SiteEUIWN(kBtu/sf)               3370 non-null   float64
#  31  SourceEUI(kBtu/sf)               3367 non-null   float64
#  32  SourceEUIWN(kBtu/sf)             3367 non-null   float64
#  33  SiteEnergyUse(kBtu)              3371 non-null   float64
#  34  SiteEnergyUseWN(kBtu)            3370 non-null   float64
#  35  SteamUse(kBtu)                   3367 non-null   float64
#  36  Electricity(kWh)                 3367 non-null   float64
#  37  Electricity(kBtu)                3367 non-null   float64
#  38  NaturalGas(therms)               3367 non-null   float64
#  39  NaturalGas(kBtu)                 3367 non-null   float64
#  40  DefaultData                      3376 non-null   bool
#  41  Comments                         0 non-null      float64
#  42  ComplianceStatus                 3376 non-null   object
#  43  Outlier                          32 non-null     object
#  44  TotalGHGEmissions                3367 non-null   float64
#  45  GHGEmissionsIntensity            3367 non-null   float64
# dtypes: bool(1), float64(22), int64(8), object(15)
# memory usage: 1.2+ MB

# %% [markdown]
# #### Analyse de forme de df:
# - Lignes et colonnes: 3376, 46
#
# - Types de variables: quantitatives: 30, qualitatives: 15, bool: 1
#
# - Analyse des valeurs manquantes:
#
#      5/46 colonnes avec taux de remplissage < 50%
#
#      36/46 colonnes avec taux de remplissage à 100%.

# %% [markdown]
# #### Nettoyage des données:
# ##### Seul les bâtiments non destinées à l'habitation seront concernées dans ce projet:

# %%
df['BuildingType'].unique()
# Out:
# array(['NonResidential', 'Nonresidential COS', 'Multifamily MR (5-9)',
#        'SPS-District K-12', 'Campus', 'Multifamily LR (1-4)',
#        'Multifamily HR (10+)', 'Nonresidential WA'], dtype=object)

# %%
df0 = df[~df['BuildingType'].str.contains('Multifamily')]

# %%
#Vérification:
df0['BuildingType'].unique()
# Out:
# array(['NonResidential', 'Nonresidential COS', 'SPS-District K-12',
#        'Campus', 'Nonresidential WA'], dtype=object)

# %%
df0.shape
# Out:
# (1668, 46)

# %% [markdown]
# Le nombre de lignes a été réduit de presque 50%.

# %% [markdown]
# ##### Vérification des doublons sur l'identifiant OSEBuildingID qui doit être unique

# %%
df0.duplicated(subset=['OSEBuildingID']).sum()
# Out:
# 0

# %% [markdown]
# les identifiants (OSEBuildingID) sont uniques.

# %% [markdown]
# On remarque qu'il y a des features qui sont similaires donc on peut écarter les doublons. Par exemple:
#
# SiteEUI(kBtu/sf) & SiteEUIWN(kBtu/sf)
# SourceEUI(kBtu/sf) & SourceEUIWN(kBtu/sf)
# SiteEnergyUse(kBtu) & SiteEnergyUseWN(kBtu)
#
# WN correspond à des données normalisées par rapport aux variations de températures d'une année à l'autre. Donc on peut faire le choix de conserver ces données avec WN.

# %%
# On écarte les features non WN:
df1= df0.drop(['SiteEUI(kBtu/sf)','SourceEUI(kBtu/sf)', 'SiteEnergyUse(kBtu)'],axis=1)

# %%
#Vérification
df1.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'Address', 'City', 'State', 'ZipCode',
#        'TaxParcelIdentificationNumber', 'CouncilDistrictCode', 'Neighborhood',
#        'Latitude', 'Longitude', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUIWN(kBtu/sf)',
#        'SourceEUIWN(kBtu/sf)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'DefaultData', 'Comments', 'ComplianceStatus',
#        'Outlier', 'TotalGHGEmissions', 'GHGEmissionsIntensity'],
#       dtype='object')

# %% [markdown]
# On remarque également des features identiques avec différentes unités. Par exemple:
#
# Electricity(kWh) & Electricity(kBtu)
#
# NaturalGas(therms) & NaturalGas(kBtu)
#
# sachant que: (kBtu): the kilo-British thermal unit, is the recommended global unit of measure because it is the one most frequently used in building benchmarks and all ENERGY STAR reporting.
#
# Donc on sélectionne les features avec kBtu comme unité.

# %%
# On écarte les features autre que kBtu comme unité :
df2= df1.drop(['Electricity(kWh)','NaturalGas(therms)'],axis=1)

# %%
# Vérification:
df2.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'Address', 'City', 'State', 'ZipCode',
#        'TaxParcelIdentificationNumber', 'CouncilDistrictCode', 'Neighborhood',
#        'Latitude', 'Longitude', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUIWN(kBtu/sf)',
#        'SourceEUIWN(kBtu/sf)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kBtu)', 'NaturalGas(kBtu)', 'DefaultData', 'Comments',
#        'ComplianceStatus', 'Outlier', 'TotalGHGEmissions',
#        'GHGEmissionsIntensity'],
#       dtype='object')

# %% [markdown]
# Les variables à prédire dans le cadre de notre projet sont la consommation d'énergie du bâtiment (SiteEnergyUseWN(kBtu)) et ses émissions de CO2 (TotalGHGEmissions).
#
# A savoir:
#
# WN: Weather Normalized energy is the energy your property would have used if you had experienced 30-year average temperatures*. The weather in a given year may be much hotter or colder than your building's normal climate; weather normalized energy accounts for this difference
#
# GHGE: greenhouse gas emissions

# %%
df2['SiteEnergyUseWN(kBtu)'].isnull().sum()
# Out:
# 3

# %%
df2['TotalGHGEmissions'].isnull().sum()
# Out:
# 2

# %% [markdown]
# Ces 2 variables comportent des données manquantes, on écarte les lignes correspondantes.

# %%
# On écarte les lignes avec les données manquantes:
df3= df2[~((df2['SiteEnergyUseWN(kBtu)'].isnull()) | (df2['TotalGHGEmissions'].isnull()))]

# %%
#Vérification
df3['SiteEnergyUseWN(kBtu)'].isnull().sum()
# Out:
# 0

# %%
#Vérification
df3['TotalGHGEmissions'].isnull().sum()
# Out:
# 0

# %% [markdown]
# On écarte les colonnes qui ont un taux de remplissage très faible (seuil 50%). On a:
#
# ThirdLargestPropertyUseType: 18%
#
# ThirdLargestPropertyUseTypeGFA: 18%
#
# YearsENERGYSTARCertified: 4%
#
# Comments: 0%
#
# Outlier: 0%

# %%
df4= df3.drop(['ThirdLargestPropertyUseType','ThirdLargestPropertyUseTypeGFA','YearsENERGYSTARCertified','Comments','Outlier'],axis=1)

# %%
#Vérfication:
df4.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'Address', 'City', 'State', 'ZipCode',
#        'TaxParcelIdentificationNumber', 'CouncilDistrictCode', 'Neighborhood',
#        'Latitude', 'Longitude', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ENERGYSTARScore', 'SiteEUIWN(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)', 'Electricity(kBtu)',
#        'NaturalGas(kBtu)', 'DefaultData', 'ComplianceStatus',
#        'TotalGHGEmissions', 'GHGEmissionsIntensity'],
#       dtype='object')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1665 entries, 0 to 3375
# Data columns (total 36 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   OSEBuildingID                    1665 non-null   int64
#  1   DataYear                         1665 non-null   int64
#  2   BuildingType                     1665 non-null   object
#  3   PrimaryPropertyType              1665 non-null   object
#  4   PropertyName                     1665 non-null   object
#  5   Address                          1665 non-null   object
#  6   City                             1665 non-null   object
#  7   State                            1665 non-null   object
#  8   ZipCode                          1649 non-null   float64
#  9   TaxParcelIdentificationNumber    1665 non-null   object
#  10  CouncilDistrictCode              1665 non-null   int64
#  11  Neighborhood                     1665 non-null   object
#  12  Latitude                         1665 non-null   float64
#  13  Longitude                        1665 non-null   float64
#  14  YearBuilt                        1665 non-null   int64
#  15  NumberofBuildings                1665 non-null   float64
#  16  NumberofFloors                   1665 non-null   int64
#  17  PropertyGFATotal                 1665 non-null   int64
#  18  PropertyGFAParking               1665 non-null   int64
#  19  PropertyGFABuilding(s)           1665 non-null   int64
#  20  ListOfAllPropertyUseTypes        1665 non-null   object
#  21  LargestPropertyUseType           1661 non-null   object
#  22  LargestPropertyUseTypeGFA        1661 non-null   float64
#  23  SecondLargestPropertyUseType     854 non-null    object
#  24  SecondLargestPropertyUseTypeGFA  854 non-null    float64
#  25  ENERGYSTARScore                  1093 non-null   float64
#  26  SiteEUIWN(kBtu/sf)               1665 non-null   float64
#  27  SourceEUIWN(kBtu/sf)             1665 non-null   float64
#  28  SiteEnergyUseWN(kBtu)            1665 non-null   float64
#  29  SteamUse(kBtu)                   1665 non-null   float64
#  30  Electricity(kBtu)                1665 non-null   float64
#  31  NaturalGas(kBtu)                 1665 non-null   float64
#  32  DefaultData                      1665 non-null   bool
#  33  ComplianceStatus                 1665 non-null   object
#  34  TotalGHGEmissions                1665 non-null   float64
#  35  GHGEmissionsIntensity            1665 non-null   float64
# dtypes: bool(1), float64(15), int64(8), object(12)
# memory usage: 469.9+ KB

# %%
#Heatmap appliqué pour visualiser les données manquantes
plt.rcParams["figure.figsize"] = (28,4)
sns.heatmap(df4.isnull(),yticklabels=False, cbar=False,cmap='viridis')

# %%
# Calcul du taux de remplissage par colonne:
col= df4.columns.tolist()
df_rate_4= pd.DataFrame(columns=['col','Taux de remplissage'])
for column in col:
    col_obj= df4[column]
    null_rate=round(1-(col_obj.isnull().sum()/float(len(df4))),2)
    df_rate_4= df_rate_4.append({'col':column, 'Taux de remplissage':null_rate },ignore_index=True)

# %%
df_rate_4.head()
# Out:
#                    col  Taux de remplissage
# 0        OSEBuildingID                  1.0
# 1             DataYear                  1.0
# 2         BuildingType                  1.0
# 3  PrimaryPropertyType                  1.0
# 4         PropertyName                  1.0

# %%
df_rate_4[~(df_rate_4['Taux de remplissage']==1)]
# Out:
#                                 col  Taux de remplissage
# 8                           ZipCode                 0.99
# 23     SecondLargestPropertyUseType                 0.51
# 24  SecondLargestPropertyUseTypeGFA                 0.51
# 25                  ENERGYSTARScore                 0.66

# %% [markdown]
# ##### Analyse de forme de df4:
# - Lignes et colonnes: 1665, 36
#
# - Types de variables: quantitatives: 23, qualitatives: 12
#
# - Analyse des valeurs manquantes:
#
#      32/36 colonnes à 100% - 2/36 colonnes à 51%  -  1/36 à 66% -  1/36 à 99%

# %% [markdown]
# On écarte les 2 features (SecondLargestPropertyUseType) et (SecondLargestPropertyUseTypeGFA) vu leur taux de remplissage.

# %%
df4.drop(['SecondLargestPropertyUseType','SecondLargestPropertyUseTypeGFA'],axis=1,inplace=True)

# %% [markdown]
# On écarte les données manquantes pour les features (LargestPropertyUseType) et (LargestPropertyUseTypeGFA)

# %%
df4[df4['LargestPropertyUseType'].isna()]['LargestPropertyUseType']
# Out:
# 353     NaN
# 1147    NaN
# 2414    NaN
# 2459    NaN
# Name: LargestPropertyUseType, dtype: object

# %%
df4[df4['LargestPropertyUseTypeGFA'].isna()]['LargestPropertyUseTypeGFA']
# Out:
# 353    NaN
# 1147   NaN
# 2414   NaN
# 2459   NaN
# Name: LargestPropertyUseTypeGFA, dtype: float64

# %% [markdown]
# On remarque que les données manquantes correspondent au même index.

# %%
df4.drop(df4[df4['LargestPropertyUseType'].isna()].index,inplace=True)

# %% [markdown]
# On écarte les données manquantes pour le feature (ZipCode)

# %%
len(df4[df4['ZipCode'].isna()]['ZipCode'])
# Out:
# 16

# %%
df4.drop(df4[df4['ZipCode'].isna()].index,inplace=True)

# %% [markdown]
# #### Feature engineering et exploration de données

# %% [markdown]
# ##### Analyse des types de bâtiments

# %%
df4['BuildingType'].unique()
# Out:
# array(['NonResidential', 'Nonresidential COS', 'SPS-District K-12',
#        'Campus', 'Nonresidential WA'], dtype=object)

# %% [markdown]
# SPS: Seattle Public School
#
# COS: Coefficient d'Occupation du Sol. Le COS est différent d'une zone de la commune à l'autre.
# Un coefficient de 1 signifie que la totalité du terrain peut être utilisée pour la construction.
# Un COS de 0,4 indique que l'on peut utiliser 400 m² de surface de plancher sur un terrain constructible de 1 000 m².
#
# Campus: Vaste terrain construit de bâtiments universitaires et de résidences étudiantes, aux allures de parc, aux États-Unis et au Canada.

# %%
# On visualise la répartition des types de bâtiment dans (BuildingType):
building_type = df4.groupby(by='BuildingType')['OSEBuildingID'].nunique()
fig, ax = plt.subplots(figsize=(8,8))
ax.pie(building_type.values, labels=building_type.index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x269ca0838c8>,
#   <matplotlib.patches.Wedge at 0x269ca08f188>,
#   <matplotlib.patches.Wedge at 0x269ca08fa48>,
#   <matplotlib.patches.Wedge at 0x269ca099348>,
#   <matplotlib.patches.Wedge at 0x269ca099f48>],
#  [Text(1.0988447470950395, 0.050400612909357136, 'Campus'),
#   Text(-1.0586651002064702, 0.29871090640420944, 'NonResidential'),
#   Text(0.9600661668931799, -0.536910565352403, 'Nonresidential COS'),
#   Text(1.0230631410300146, -0.4041556747910395, 'Nonresidential WA'),
#   Text(1.0807905456662437, -0.20467485531560478, 'SPS-District K-12')],
#  [Text(0.5993698620518397, 0.02749124340510389, '1.5%'),
#   Text(-0.577453691021711, 0.16293322167502333, '88.3%'),
#   Text(0.5236724546690071, -0.2928603083740379, '4.2%'),
#   Text(0.5580344405618262, -0.2204485498860215, '0.1%'),
#   Text(0.589522115817951, -0.11164083017214806, '6.0%')])

# %% [markdown]
# On remarque que les bâtiments de type (NonResidential) représentent la majorité des bâtiments (87.5%).

# %% [markdown]
# On va calculer la consommation/emission moyenne pour chaque type de bâtiment

# %%
# A l'aide du barplot on visualise la consommation moyenne pour chaque type de bâtiment:
df4_conso= df4.groupby(by='BuildingType').agg(mean_conso=("SiteEnergyUseWN(kBtu)","mean"))
df4_conso = df4_conso.reset_index()
sns.barplot(x="BuildingType",y="mean_conso",data=df4_conso)

# %%
# A l'aide du barplot on visualise l'émission moyenne pour chaque type de bâtiment:
df4_em= df4.groupby(by='BuildingType').agg(mean_emission=("TotalGHGEmissions","mean"))
df4_em= df4_em.reset_index()
sns.barplot(x="BuildingType",y="mean_emission",data=df4_em)

# %%
# On crée une copie de df4:
df5= df4.copy()

# %% [markdown]
# On analyse les catégories de bâtiment dans le type (NonResidential)

# %%
df5.loc[(df5['BuildingType']=="NonResidential"),'PrimaryPropertyType'].value_counts()
# Out:
# Small- and Mid-Sized Office    286
# Other                          185
# Warehouse                      180
# Large Office                   167
# Mixed Use Property             101
# Retail Store                    91
# Hotel                           75
# Worship Facility                71
# Distribution Center             51
# Supermarket / Grocery Store     40
# K-12 School                     39
# Medical Office                  38
# Self-Storage Facility           27
# Residence Hall                  21
# Senior Care Community           20
# University                      17
# Refrigerated Warehouse          12
# Laboratory                      10
# Hospital                        10
# Restaurant                      10
# Low-Rise Multifamily             2
# Name: PrimaryPropertyType, dtype: int64

# %% [markdown]
# On fait un plot de type histogramme afin de voir la distribution des bâtiments par année de construction.

# %%
fig = plt.figure(figsize=(12,8))
ax = sns.distplot(df5['YearBuilt'],kde= False)
ax.set_xlabel("Année de construction")
ax.set_ylabel("Nombre de bâtiments")
plt.title("Distribution des années de construction des bâtiments")
# Out:
# Text(0.5, 1.0, 'Distribution des années de construction des bâtiments')

# %%
df4['DataYear'].unique()
# Out:
# array([2016], dtype=int64)

# %% [markdown]
# On peut à partir de la variable (DataYear) et (YearBuilt) construire une nouvelle variable qui donne l'âge du bâtiment.

# %%
df5['BuildingAge']= df5['DataYear']-df5['YearBuilt']

# %%
# On écarte les 2 variables (DataYear) et (YearBuilt):
df6= df5.drop(['DataYear','YearBuilt'],axis=1)

# %%
#Vérification:
df6.columns
# Out:
# Index(['OSEBuildingID', 'BuildingType', 'PrimaryPropertyType', 'PropertyName',
#        'Address', 'City', 'State', 'ZipCode', 'TaxParcelIdentificationNumber',
#        'CouncilDistrictCode', 'Neighborhood', 'Latitude', 'Longitude',
#        'NumberofBuildings', 'NumberofFloors', 'PropertyGFATotal',
#        'PropertyGFAParking', 'PropertyGFABuilding(s)',
#        'ListOfAllPropertyUseTypes', 'LargestPropertyUseType',
#        'LargestPropertyUseTypeGFA', 'ENERGYSTARScore', 'SiteEUIWN(kBtu/sf)',
#        'SourceEUIWN(kBtu/sf)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kBtu)', 'NaturalGas(kBtu)', 'DefaultData',
#        'ComplianceStatus', 'TotalGHGEmissions', 'GHGEmissionsIntensity',
#        'BuildingAge'],
#       dtype='object')

# %%
df6['BuildingAge']
# Out:
# 0       89
# 1       20
# 2       47
# 3       90
# 4       36
#         ..
# 3339    87
# 3340     3
# 3347     1
# 3356     1
# 3359    54
# Name: BuildingAge, Length: 1645, dtype: int64

# %%
# Réprésentation avec un plot de distribution:
fig = plt.figure(figsize=(12,8))
ax = sns.distplot(df6['BuildingAge'],kde= False)
ax.set_xlabel("Age du bâtiment")
ax.set_ylabel("Nombre de bâtiments")
plt.title("Distribution des âges des bâtiments")
# Out:
# Text(0.5, 1.0, 'Distribution des âges des bâtiments')

# %% [markdown]
# ##### Identification de Corrélation linéaire entre les variables:

# %%
corr=df6.corr()

# %%
corr
# Out:
#                            OSEBuildingID   ZipCode  CouncilDistrictCode  \
# OSEBuildingID                   1.000000  0.137339            -0.161401
# ZipCode                         0.137339  1.000000            -0.192178
# CouncilDistrictCode            -0.161401 -0.192178             1.000000
# Latitude                        0.031703  0.000997             0.526120
# Longitude                       0.095279 -0.015063            -0.329456
# NumberofBuildings               0.049230 -0.014909            -0.017614
# NumberofFloors                 -0.249184 -0.145344             0.278272
# PropertyGFATotal               -0.145614 -0.059956             0.108963
# PropertyGFAParking             -0.215860 -0.097503             0.193199
# PropertyGFABuilding(s)         -0.120259 -0.048234             0.085283
# LargestPropertyUseTypeGFA      -0.108223 -0.041171             0.068632
# ENERGYSTARScore                -0.048397 -0.001860             0.095546
# SiteEUIWN(kBtu/sf)             -0.015842 -0.076031             0.067753
# SourceEUIWN(kBtu/sf)           -0.049574 -0.068267             0.099183
# SiteEnergyUseWN(kBtu)          -0.180411 -0.058633             0.067639
# SteamUse(kBtu)                 -0.009668 -0.049582             0.007940
# Electricity(kBtu)              -0.097161 -0.047503             0.074084
# NaturalGas(kBtu)               -0.073287 -0.024521            -0.010418
# DefaultData                    -0.043462  0.002025            -0.108314
# TotalGHGEmissions              -0.072709 -0.053455             0.011882
# GHGEmissionsIntensity           0.063727 -0.070045            -0.008756
# BuildingAge                     0.011243 -0.096259             0.046276
#
#                            Latitude  Longitude  NumberofBuildings  \
# OSEBuildingID              0.031703   0.095279           0.049230
# ZipCode                    0.000997  -0.015063          -0.014909
# CouncilDistrictCode        0.526120  -0.329456          -0.017614
# Latitude                   1.000000  -0.087392           0.020572
# Longitude                 -0.087392   1.000000           0.021437
# NumberofBuildings          0.020572   0.021437           1.000000
# NumberofFloors            -0.009010  -0.013527          -0.023562
# PropertyGFATotal           0.006568   0.021632           0.734821
# PropertyGFAParking         0.040106  -0.027865          -0.011729
# PropertyGFABuilding(s)     0.000911   0.026772           0.770484
# LargestPropertyUseTypeGFA  0.006728   0.030113           0.796931
# ENERGYSTARScore            0.041409   0.001849          -0.035849
# SiteEUIWN(kBtu/sf)         0.076703  -0.014467          -0.000599
# SourceEUIWN(kBtu/sf)       0.076894  -0.018181          -0.004717
# SiteEnergyUseWN(kBtu)     -0.009806   0.024784           0.088469
# SteamUse(kBtu)            -0.004897   0.021112           0.408545
# Electricity(kBtu)          0.011640   0.023130           0.757684
# NaturalGas(kBtu)           0.001465   0.036787           0.062162
# DefaultData               -0.033646   0.105963          -0.013473
# TotalGHGEmissions          0.000442   0.040758           0.418481
# GHGEmissionsIntensity      0.035560   0.012360           0.027380
# BuildingAge               -0.067806  -0.015256           0.030530
#
#                            NumberofFloors  PropertyGFATotal  \
# OSEBuildingID                   -0.249184         -0.145614
# ZipCode                         -0.145344         -0.059956
# CouncilDistrictCode              0.278272          0.108963
# Latitude                        -0.009010          0.006568
# Longitude                       -0.013527          0.021632
# NumberofBuildings               -0.023562          0.734821
# NumberofFloors                   1.000000          0.405168
# PropertyGFATotal                 0.405168          1.000000
# PropertyGFAParking               0.502978          0.374812
# PropertyGFABuilding(s)           0.349129          0.990465
# LargestPropertyUseTypeGFA        0.333261          0.977631
# ENERGYSTARScore                  0.121323          0.123809
# SiteEUIWN(kBtu/sf)               0.017821          0.004978
# SourceEUIWN(kBtu/sf)             0.060323          0.024377
# SiteEnergyUseWN(kBtu)            0.316656          0.371999
# SteamUse(kBtu)                   0.092595          0.452742
# Electricity(kBtu)                0.281334          0.861754
# NaturalGas(kBtu)                 0.034519          0.154052
# DefaultData                     -0.076502         -0.030207
# TotalGHGEmissions                0.129498          0.524380
# GHGEmissionsIntensity           -0.045013         -0.005792
# BuildingAge                     -0.096721         -0.104261
#
#                            PropertyGFAParking  PropertyGFABuilding(s)  ...  \
# OSEBuildingID                       -0.215860               -0.120259  ...
# ZipCode                             -0.097503               -0.048234  ...
# CouncilDistrictCode                  0.193199                0.085283  ...
# Latitude                             0.040106                0.000911  ...
# Longitude                           -0.027865                0.026772  ...
# NumberofBuildings                   -0.011729                0.770484  ...
# NumberofFloors                       0.502978                0.349129  ...
# PropertyGFATotal                     0.374812                0.990465  ...
# PropertyGFAParking                   1.000000                0.243514  ...
# PropertyGFABuilding(s)               0.243514                1.000000  ...
# LargestPropertyUseTypeGFA            0.272624                0.982248  ...
# ENERGYSTARScore                      0.092479                0.118364  ...
# SiteEUIWN(kBtu/sf)                   0.052270               -0.002559  ...
# SourceEUIWN(kBtu/sf)                 0.099645                0.010696  ...
# SiteEnergyUseWN(kBtu)                0.208135                0.358242  ...
# SteamUse(kBtu)                       0.001155                0.473469  ...
# Electricity(kBtu)                    0.200593                0.871726  ...
# NaturalGas(kBtu)                     0.027877                0.157021  ...
# DefaultData                         -0.070427               -0.021136  ...
# TotalGHGEmissions                    0.057774                0.540001  ...
# GHGEmissionsIntensity               -0.091853                0.007590  ...
# BuildingAge                         -0.279320               -0.067567  ...
#
#                            SiteEUIWN(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# OSEBuildingID                       -0.015842             -0.049574
# ZipCode                             -0.076031             -0.068267
# CouncilDistrictCode                  0.067753              0.099183
# Latitude                             0.076703              0.076894
# Longitude                           -0.014467             -0.018181
# NumberofBuildings                   -0.000599             -0.004717
# NumberofFloors                       0.017821              0.060323
# PropertyGFATotal                     0.004978              0.024377
# PropertyGFAParking                   0.052270              0.099645
# PropertyGFABuilding(s)              -0.002559              0.010696
# LargestPropertyUseTypeGFA           -0.003434              0.005860
# ENERGYSTARScore                     -0.354613             -0.299071
# SiteEUIWN(kBtu/sf)                   1.000000              0.945415
# SourceEUIWN(kBtu/sf)                 0.945415              1.000000
# SiteEnergyUseWN(kBtu)                0.371702              0.361562
# SteamUse(kBtu)                       0.078488              0.061304
# Electricity(kBtu)                    0.231314              0.268733
# NaturalGas(kBtu)                     0.240872              0.156726
# DefaultData                         -0.109661             -0.115718
# TotalGHGEmissions                    0.248445              0.190239
# GHGEmissionsIntensity                0.713946              0.513796
# BuildingAge                         -0.118242             -0.155222
#
#                            SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# OSEBuildingID                          -0.180411       -0.009668
# ZipCode                                -0.058633       -0.049582
# CouncilDistrictCode                     0.067639        0.007940
# Latitude                               -0.009806       -0.004897
# Longitude                               0.024784        0.021112
# NumberofBuildings                       0.088469        0.408545
# NumberofFloors                          0.316656        0.092595
# PropertyGFATotal                        0.371999        0.452742
# PropertyGFAParking                      0.208135        0.001155
# PropertyGFABuilding(s)                  0.358242        0.473469
# LargestPropertyUseTypeGFA               0.366719        0.507810
# ENERGYSTARScore                        -0.079366       -0.038943
# SiteEUIWN(kBtu/sf)                      0.371702        0.078488
# SourceEUIWN(kBtu/sf)                    0.361562        0.061304
# SiteEnergyUseWN(kBtu)                   1.000000        0.471117
# SteamUse(kBtu)                          0.471117        1.000000
# Electricity(kBtu)                       0.573103        0.547623
# NaturalGas(kBtu)                        0.723389        0.018657
# DefaultData                            -0.050515       -0.021491
# TotalGHGEmissions                       0.855953        0.684006
# GHGEmissionsIntensity                   0.442278        0.196658
# BuildingAge                            -0.132656        0.003854
#
#                            Electricity(kBtu)  NaturalGas(kBtu)  DefaultData  \
# OSEBuildingID                      -0.097161         -0.073287    -0.043462
# ZipCode                            -0.047503         -0.024521     0.002025
# CouncilDistrictCode                 0.074084         -0.010418    -0.108314
# Latitude                            0.011640          0.001465    -0.033646
# Longitude                           0.023130          0.036787     0.105963
# NumberofBuildings                   0.757684          0.062162    -0.013473
# NumberofFloors                      0.281334          0.034519    -0.076502
# PropertyGFATotal                    0.861754          0.154052    -0.030207
# PropertyGFAParking                  0.200593          0.027877    -0.070427
# PropertyGFABuilding(s)              0.871726          0.157021    -0.021136
# LargestPropertyUseTypeGFA           0.884083          0.173501    -0.015685
# ENERGYSTARScore                    -0.028112         -0.117846     0.190283
# SiteEUIWN(kBtu/sf)                  0.231314          0.240872    -0.109661
# SourceEUIWN(kBtu/sf)                0.268733          0.156726    -0.115718
# SiteEnergyUseWN(kBtu)               0.573103          0.723389    -0.050515
# SteamUse(kBtu)                      0.547623          0.018657    -0.021491
# Electricity(kBtu)                   1.000000          0.277549    -0.046694
# NaturalGas(kBtu)                    0.277549          1.000000    -0.016473
# DefaultData                        -0.046694         -0.016473     1.000000
# TotalGHGEmissions                   0.686479          0.725921    -0.032070
# GHGEmissionsIntensity               0.167629          0.511101    -0.062723
# BuildingAge                        -0.075036         -0.058244    -0.056464
#
#                            TotalGHGEmissions  GHGEmissionsIntensity  \
# OSEBuildingID                      -0.072709               0.063727
# ZipCode                            -0.053455              -0.070045
# CouncilDistrictCode                 0.011882              -0.008756
# Latitude                            0.000442               0.035560
# Longitude                           0.040758               0.012360
# NumberofBuildings                   0.418481               0.027380
# NumberofFloors                      0.129498              -0.045013
# PropertyGFATotal                    0.524380              -0.005792
# PropertyGFAParking                  0.057774              -0.091853
# PropertyGFABuilding(s)              0.540001               0.007590
# LargestPropertyUseTypeGFA           0.572730               0.033927
# ENERGYSTARScore                    -0.108104              -0.297707
# SiteEUIWN(kBtu/sf)                  0.248445               0.713946
# SourceEUIWN(kBtu/sf)                0.190239               0.513796
# SiteEnergyUseWN(kBtu)               0.855953               0.442278
# SteamUse(kBtu)                      0.684006               0.196658
# Electricity(kBtu)                   0.686479               0.167629
# NaturalGas(kBtu)                    0.725921               0.511101
# DefaultData                        -0.032070              -0.062723
# TotalGHGEmissions                   1.000000               0.481915
# GHGEmissionsIntensity               0.481915               1.000000
# BuildingAge                        -0.050833               0.010892
#
#                            BuildingAge
# OSEBuildingID                 0.011243
# ZipCode                      -0.096259
# CouncilDistrictCode           0.046276
# Latitude                     -0.067806
# Longitude                    -0.015256
# NumberofBuildings             0.030530
# NumberofFloors               -0.096721
# PropertyGFATotal             -0.104261
# PropertyGFAParking           -0.279320
# PropertyGFABuilding(s)       -0.067567
# LargestPropertyUseTypeGFA    -0.070906
# ENERGYSTARScore               0.031179
# SiteEUIWN(kBtu/sf)           -0.118242
# SourceEUIWN(kBtu/sf)         -0.155222
# SiteEnergyUseWN(kBtu)        -0.132656
# SteamUse(kBtu)                0.003854
# Electricity(kBtu)            -0.075036
# NaturalGas(kBtu)             -0.058244
# DefaultData                  -0.056464
# TotalGHGEmissions            -0.050833
# GHGEmissionsIntensity         0.010892
# BuildingAge                   1.000000
#
# [22 rows x 22 columns]

# %%
# Heatmap de corrélation linéraire entre les variables:
fig = plt.figure(figsize=(22,8))
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr,annot=True,mask=mask,cmap='BrBG',vmin=-1, vmax=1)

# %% [markdown]
# On rappelle que les variables target de prédictions sont: (TotalGHGEmissions) et (SiteEnergyUseWN(kBtu)).
#
# On identifie les variables par paires qui sont fortement corrélées entre elles.
#
# On peut définir 0.7 comme seuil de cette forte corrélation.

# %%
corr.unstack()
# Out:
# OSEBuildingID  OSEBuildingID            1.000000
#                ZipCode                  0.137339
#                CouncilDistrictCode     -0.161401
#                Latitude                 0.031703
#                Longitude                0.095279
#                                           ...
# BuildingAge    NaturalGas(kBtu)        -0.058244
#                DefaultData             -0.056464
#                TotalGHGEmissions       -0.050833
#                GHGEmissionsIntensity    0.010892
#                BuildingAge              1.000000
# Length: 484, dtype: float64

# %%
corr_paires= corr.unstack().sort_values(ascending=False)

# %%
corr_paires
# Out:
# BuildingAge                BuildingAge                  1.000000
# LargestPropertyUseTypeGFA  LargestPropertyUseTypeGFA    1.000000
# DefaultData                DefaultData                  1.000000
# NaturalGas(kBtu)           NaturalGas(kBtu)             1.000000
# Electricity(kBtu)          Electricity(kBtu)            1.000000
#                                                           ...
# SourceEUIWN(kBtu/sf)       ENERGYSTARScore             -0.299071
# CouncilDistrictCode        Longitude                   -0.329456
# Longitude                  CouncilDistrictCode         -0.329456
# SiteEUIWN(kBtu/sf)         ENERGYSTARScore             -0.354613
# ENERGYSTARScore            SiteEUIWN(kBtu/sf)          -0.354613
# Length: 484, dtype: float64

# %%
seuil_corr= 0.7
forte_corr= pd.DataFrame(corr_paires[(abs(corr_paires) > seuil_corr)])

# %%
forte_corr
# Out:
#                                                             0
# BuildingAge               BuildingAge                1.000000
# LargestPropertyUseTypeGFA LargestPropertyUseTypeGFA  1.000000
# DefaultData               DefaultData                1.000000
# NaturalGas(kBtu)          NaturalGas(kBtu)           1.000000
# Electricity(kBtu)         Electricity(kBtu)          1.000000
# SteamUse(kBtu)            SteamUse(kBtu)             1.000000
# SiteEnergyUseWN(kBtu)     SiteEnergyUseWN(kBtu)      1.000000
# SourceEUIWN(kBtu/sf)      SourceEUIWN(kBtu/sf)       1.000000
# SiteEUIWN(kBtu/sf)        SiteEUIWN(kBtu/sf)         1.000000
# ENERGYSTARScore           ENERGYSTARScore            1.000000
# PropertyGFABuilding(s)    PropertyGFABuilding(s)     1.000000
# GHGEmissionsIntensity     GHGEmissionsIntensity      1.000000
# PropertyGFAParking        PropertyGFAParking         1.000000
# PropertyGFATotal          PropertyGFATotal           1.000000
# NumberofFloors            NumberofFloors             1.000000
# NumberofBuildings         NumberofBuildings          1.000000
# Longitude                 Longitude                  1.000000
# Latitude                  Latitude                   1.000000
# CouncilDistrictCode       CouncilDistrictCode        1.000000
# ZipCode                   ZipCode                    1.000000
# TotalGHGEmissions         TotalGHGEmissions          1.000000
# OSEBuildingID             OSEBuildingID              1.000000
# PropertyGFABuilding(s)    PropertyGFATotal           0.990465
# PropertyGFATotal          PropertyGFABuilding(s)     0.990465
# PropertyGFABuilding(s)    LargestPropertyUseTypeGFA  0.982248
# LargestPropertyUseTypeGFA PropertyGFABuilding(s)     0.982248
#                           PropertyGFATotal           0.977631
# PropertyGFATotal          LargestPropertyUseTypeGFA  0.977631
# SiteEUIWN(kBtu/sf)        SourceEUIWN(kBtu/sf)       0.945415
# SourceEUIWN(kBtu/sf)      SiteEUIWN(kBtu/sf)         0.945415
# LargestPropertyUseTypeGFA Electricity(kBtu)          0.884083
# Electricity(kBtu)         LargestPropertyUseTypeGFA  0.884083
# PropertyGFABuilding(s)    Electricity(kBtu)          0.871726
# Electricity(kBtu)         PropertyGFABuilding(s)     0.871726
#                           PropertyGFATotal           0.861754
# PropertyGFATotal          Electricity(kBtu)          0.861754
# TotalGHGEmissions         SiteEnergyUseWN(kBtu)      0.855953
# SiteEnergyUseWN(kBtu)     TotalGHGEmissions          0.855953
# NumberofBuildings         LargestPropertyUseTypeGFA  0.796931
# LargestPropertyUseTypeGFA NumberofBuildings          0.796931
# PropertyGFABuilding(s)    NumberofBuildings          0.770484
# NumberofBuildings         PropertyGFABuilding(s)     0.770484
# Electricity(kBtu)         NumberofBuildings          0.757684
# NumberofBuildings         Electricity(kBtu)          0.757684
#                           PropertyGFATotal           0.734821
# PropertyGFATotal          NumberofBuildings          0.734821
# TotalGHGEmissions         NaturalGas(kBtu)           0.725921
# NaturalGas(kBtu)          TotalGHGEmissions          0.725921
#                           SiteEnergyUseWN(kBtu)      0.723389
# SiteEnergyUseWN(kBtu)     NaturalGas(kBtu)           0.723389
# GHGEmissionsIntensity     SiteEUIWN(kBtu/sf)         0.713946
# SiteEUIWN(kBtu/sf)        GHGEmissionsIntensity      0.713946

# %% [markdown]
# Dans cette partie s'exploration de données, on va utiliser la variable (SiteEUIWN(kBtu/sf)) qui est indépendante de la surface du site, contrairenement à (SiteEnergyUseWN(kBtu))

# %% [markdown]
# Visualisation de la variation de certaines variables en fonction des variables target:
# (SiteEUIWN(kBtu/sf)) et (TotalGHGEmissions)
#
# PS: GHGEmissions: Grean House Gas Emissions

# %% [markdown]
# ACTION POUR CES PAIRES CORRELEES

# %% [markdown]
# ##### Boxplot de distribution des variables (TotalGHGEmissions) et (SiteEUIWN(kBtu/sf))

# %%
plt.figure(figsize=(5,3))
df5['SiteEUIWN(kBtu/sf)'].plot.box(showmeans=True)

# %%
plt.figure(figsize=(5,3))
df5['TotalGHGEmissions'].plot.box(showmeans=True)

# %% [markdown]
# Filtrage sur les outliers: On va écarter les valeurs oultliers vérifiant:
#
# value > Q3+ 1.5* IQR Or value < Q1 - 1.5* IQR

# %% [markdown]
# On écarte les outliers de la variable: (TotalGHGEmissions)

# %%
q3_em= df6['TotalGHGEmissions'].quantile(0.75)
q1_em= df6['TotalGHGEmissions'].quantile(0.25)
from scipy.stats import iqr
iqr_em= iqr(df6['TotalGHGEmissions'])

# %%
df7= df6[~ ((df6['TotalGHGEmissions'] > (q3_em + 1.5*iqr_em)) | (df6['TotalGHGEmissions'] < (q1_em - 1.5*iqr_em)))]

# %%
#Vérification:
plt.figure(figsize=(5,3))
df7['TotalGHGEmissions'].plot.box(showmeans=True)

# %%
df7[df7['TotalGHGEmissions']<0]
# Out:
#       OSEBuildingID    BuildingType          PrimaryPropertyType  \
# 3206          49784  NonResidential  Small- and Mid-Sized Office
#
#         PropertyName              Address     City State  ZipCode  \
# 3206  Bullitt Center  1501 E. Madison St.  Seattle    WA  98122.0
#
#      TaxParcelIdentificationNumber  CouncilDistrictCode  ...  \
# 3206                    7234600195                    3  ...
#
#      SourceEUIWN(kBtu/sf)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# 3206                 -2.1            240132.0938             0.0
#
#       Electricity(kBtu)  NaturalGas(kBtu)  DefaultData  ComplianceStatus  \
# 3206          -115417.0               0.0        False         Compliant
#
#       TotalGHGEmissions GHGEmissionsIntensity BuildingAge
# 3206               -0.8                 -0.02           3
#
# [1 rows x 33 columns]

# %% [markdown]
# On écarte la ligne qui correspond à la donnée aberrante (TotalGHGEmissions)<0

# %%
df8= df7.drop(df7[df7['TotalGHGEmissions']<0].index)

# %%
# Vérification:
df8[df8['TotalGHGEmissions']<0]
# Out:
# Empty DataFrame
# Columns: [OSEBuildingID, BuildingType, PrimaryPropertyType, PropertyName, Address, City, State, ZipCode, TaxParcelIdentificationNumber, CouncilDistrictCode, Neighborhood, Latitude, Longitude, NumberofBuildings, NumberofFloors, PropertyGFATotal, PropertyGFAParking, PropertyGFABuilding(s), ListOfAllPropertyUseTypes, LargestPropertyUseType, LargestPropertyUseTypeGFA, ENERGYSTARScore, SiteEUIWN(kBtu/sf), SourceEUIWN(kBtu/sf), SiteEnergyUseWN(kBtu), SteamUse(kBtu), Electricity(kBtu), NaturalGas(kBtu), DefaultData, ComplianceStatus, TotalGHGEmissions, GHGEmissionsIntensity, BuildingAge]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# On écarte les outliers de la variable: (SiteEUIWN(kBtu/sf))

# %%
q3_eu= df8['SiteEUIWN(kBtu/sf)'].quantile(0.75)
q1_eu= df8['SiteEUIWN(kBtu/sf)'].quantile(0.25)
from scipy.stats import iqr
iqr_eu= iqr(df8['SiteEUIWN(kBtu/sf)'])

# %%
df9= df8[~ ((df8['SiteEUIWN(kBtu/sf)'] > (q3_eu + 1.5*iqr_eu)) | (df8['SiteEUIWN(kBtu/sf)'] < (q1_eu - 1.5*iqr_eu)))]

# %%
#Vérification:
plt.figure(figsize=(5,3))
df9['SiteEUIWN(kBtu/sf)'].plot.box(showmeans=True)

# %%
# faire des barplot à la place
df9.plot.scatter(x='BuildingAge',y='TotalGHGEmissions')

# %%
df9.plot.scatter(x='BuildingAge',y='SiteEUIWN(kBtu/sf)')

# %% [markdown]
# Distribution du niveau de consommation d'énergie par position géographique

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Longitude',y='Latitude',data=df9,hue='SiteEUIWN(kBtu/sf)',edgecolor=None)
#'RdYlGn'

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Longitude',y='Latitude',data=df9,hue='TotalGHGEmissions',edgecolor=None)

# %%
#Heatmap appliqué pour visualiser les données manquantes
plt.rcParams["figure.figsize"] = (28,4)
sns.heatmap(df9.isnull(),yticklabels=False, cbar=False,cmap='viridis')

# %%
# on charge le df9 dans un fichier csv:
df9.to_csv('consoBat_df9.csv',index=False)
